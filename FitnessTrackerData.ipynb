# %% [markdown]
# ### <span style="color:red">The dataset was obtained from Kaggle at the following link: https://www.kaggle.com/datasets/nadeemajeedch/fitness-tracker-dataset.</span>

# %% [markdown]
# # <p style="background-color:blue;font-family:newtimeroman;font-size:100%;color:white;text-align:center;border-radius:20px 20px;"><b>About the Dataset:</b></p>
#
#
#
# - Age: The age of the individual (years).
# - Gender: The gender of the individual (e.g., Male, Female).
# - Weight (kg): The weight of the individual (kilograms).
# - Height (m): The height of the individual (meters).
# - Max_BPM: The maximum heart rate recorded during exercise.
# - Avg_BPM: The average heart rate during a workout session per minute.
# - Resting_BPM: The resting heart rate per minute.
# - Session_Duration (hours): The duration of the exercise session (hours).
# - Calories_Burned: The total calories burned during a workout session.
# - Workout_Type: The type of exercise performed (e.g., Cardio, Strength, Yoga).
# - Fat_Percentage: Body fat percentage.
# - Water_Intake (liters): Water intake during or after exercise, measured in liters.
# - Workout_Frequency (days/week): The number of days the individual works out per week.
# - Experience_Level: The fitness experience level (e.g., Beginner, Intermediate, Advanced).
# - BMI: Body Mass Index, calculated as weight (kg) / height (m)^2.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
df = pd.read_csv("Fitness Tracker Dataset.csv")
df
# Out:
#        Age  Gender  Weight (kg)  Height (m) Max_BPM  Avg_BPM  Resting_BPM  \
# 0     34.0  Female         86.7        1.86     174    152.0         74.0
# 1     26.0  Female         84.7        1.83     166    156.0         73.0
# 2     22.0    Male         64.8        1.85     187    166.0         64.0
# 3     54.0  Female         75.3        1.82     187    169.0         58.0
# 4     34.0  Female         52.8        1.74     177    169.0         66.0
# ...    ...     ...          ...         ...     ...      ...          ...
# 1795  54.0    Male         88.5        2.00     173    134.0         58.0
# 1796  52.0    Male         84.3        1.69     164    169.0         54.0
# 1797  47.0    Male         70.1        1.84     188    129.0         67.0
# 1798  35.0    Male         49.3        1.71     180    152.0         73.0
# 1799  40.0    Male         79.5        1.92     184    156.0         52.0
#
#       Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# 0                         1.12            712.0     Strength            12.8
# 1                         1.00            833.0     Strength            27.9
# 2                         1.24           1678.0       Cardio            28.7
# 3                         1.45            628.0       Cardio            31.8
# 4                         1.60           1286.0     Strength            26.4
# ...                        ...              ...          ...             ...
# 1795                      1.11           1388.0         HIIT            27.7
# 1796                      0.77           1367.0         HIIT            32.6
# 1797                      1.20           1261.0     Strength            28.4
# 1798                      1.04            956.0       Cardio            32.9
# 1799                      1.29           1178.0     Strength            14.7
#
#       Water_Intake (liters)  Workout_Frequency (days/week)  Experience_Level  \
# 0                       2.4                            5.0               2.0
# 1                       2.8                            5.0               2.0
# 2                       1.9                            3.0               2.0
# 3                       2.4                            4.0               1.0
# 4                       3.2                            4.0               2.0
# ...                     ...                            ...               ...
# 1795                    3.7                            3.0               2.0
# 1796                    2.9                            3.0               2.0
# 1797                    2.5                            3.0               2.0
# 1798                    1.7                            4.0               3.0
# 1799                    1.5                            4.0               1.0
#
#         BMI
# 0     14.31
# 1     33.49
# 2     12.73
# 3     20.37
# 4     20.83
# ...     ...
# 1795  36.73
# 1796  15.11
# 1797  17.99
# 1798  12.65
# 1799  23.51
#
# [1800 rows x 15 columns]

# %%
df1 = df.copy()     # We took a copy of our original data because we will be working on it.

# %%
df.info() 

# The `df.info()` method provides a quick overview of a pandas DataFrame’s structure, displaying data types, null values, 
# and memory usage for each column, which is crucial for understanding the dataset before analysis.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            1790 non-null   float64
#  1   Gender                         1729 non-null   object
#  2   Weight (kg)                    1778 non-null   float64
#  3   Height (m)                     1774 non-null   float64
#  4   Max_BPM                        1779 non-null   object
#  5   Avg_BPM                        1770 non-null   float64
#  6   Resting_BPM                    1781 non-null   float64
#  7   Session_Duration (hours)       1777 non-null   float64
#  8   Calories_Burned                1777 non-null   float64
#  9   Workout_Type                   1739 non-null   object
#  10  Fat_Percentage                 1784 non-null   float64
#  11  Water_Intake (liters)          1776 non-null   float64
#  12  Workout_Frequency (days/week)  1742 non-null   float64
#  13  Experience_Level               1743 non-null   float64
#  14  BMI                            1770 non-null   float64
# dtypes: float64(12), object(3)
# memory usage: 211.1+ KB

# %%
df.describe().T 

# This method provides a transposed summary of the descriptive statistics for a pandas DataFrame, including count, mean, standard deviation, 
# min, 25th percentile, median, 75th percentile, and max for numerical columns.
# Out:
#                                 count         mean         std     min  \
# Age                            1790.0    34.475419   12.315728   18.00
# Weight (kg)                    1778.0    67.606637   19.861408   40.00
# Height (m)                     1774.0     1.739233    0.123892    1.50
# Avg_BPM                        1770.0   146.259322   15.219516  120.00
# Resting_BPM                    1781.0    63.951151    7.936502   50.00
# Session_Duration (hours)       1777.0     1.391598    0.372342    0.50
# Calories_Burned                1777.0  1033.698931  328.049662  303.00
# Fat_Percentage                 1784.0    23.509361    5.865557   10.00
# Water_Intake (liters)          1776.0     2.706644    0.710224    1.50
# Workout_Frequency (days/week)  1742.0     3.339265    0.947955    2.00
# Experience_Level               1743.0     1.823867    0.746568    1.00
# BMI                            1770.0    19.957774    6.573175   12.32
#
#                                   25%      50%        75%      max
# Age                             23.00    33.00    45.0000    59.00
# Weight (kg)                     52.30    65.30    80.1000   129.90
# Height (m)                       1.65     1.73     1.8200     2.00
# Avg_BPM                        133.25   146.00   160.0000   169.00
# Resting_BPM                     57.00    65.00    72.0000    74.00
# Session_Duration (hours)         1.13     1.37     1.6400     2.00
# Calories_Burned                794.00  1030.00  1249.0000  1783.00
# Fat_Percentage                  20.50    24.30    27.5000    35.00
# Water_Intake (liters)            2.10     2.80     3.4000     3.70
# Workout_Frequency (days/week)    3.00     3.00     4.0000     5.00
# Experience_Level                 1.00     2.00     2.0000     3.00
# BMI                             14.78    18.69    23.5175    49.84

# %%
missing_counts = df.isnull().sum()

# The missing values have been assigned to a variable, and they are presented in the following charts.

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x=missing_counts.index, y=missing_counts.values, palette='viridis')
plt.title('Missing Values Count by Column', fontsize=16)
plt.xlabel('Columns', fontsize=10)
plt.ylabel('Count of Missing Values', fontsize=12)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# - 🎯 In the barplot, missing values are notably observed in 'Gender', 'Calories Burned', 'Water Intake', and 'Workout Frequency'.
#
# - 🎯 It also provides an initial preview for healthier data evaluation.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title('Heatmap of Missing Values', fontsize=16)
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Rows', fontsize=12)
plt.show()

# %% [markdown]
# - 🎯 The visualization of the missing value handling process was examined on a heatmap to provide a clearer view of the distribution of missing data across different features.

# %% [markdown]
# ### Filling missing values.

# %%
age_median = df["Age"].median()
age_median
# Out:
# np.float64(33.0)

# %%
df["Age"].fillna(age_median, inplace=True)

# %%
plt.figure(figsize=(6,4))

plt.hist(data=df, x ="Age", bins=30, color = "blue", alpha = 0.7)
plt.title("Histogram")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# - 🎯 Filling missing values in the 'age' column with the median helps preserve the statistical properties of the dataset and ensures that the data is represented more accurately during analysis.

# %% [markdown]
# ### We identified and corrected erroneous data entries.

# %%
df["Workout_Type"] = df["Workout_Type"].replace({"\\nStrength": "Strength", "\\tCardio":"Cardio","\\tYoga": "Yoga"})
df["Workout_Type"].value_counts()
# Out:
# Workout_Type
# Strength    476
# Cardio      439
# Yoga        435
# HIIT        389
# Name: count, dtype: int64

# %% [markdown]
# - 🎯 The incorrect categorical entries in the 'Workout Type' column have been corrected.

# %%
# df["Workout_Type"] = df["Workout_Type"].str.replace("\\nt", "")  ==>>> Second Way.

# %%
# There were incorrect values in the BMI calculation. We recalculated and reassigned them accordingly.

df['BMI'] =round(df['Weight (kg)'] / df['Height (m)'] ** 2, 2)
df['BMI'].head(10)
# Out:
# 0    25.06
# 1    25.29
# 2    18.93
# 3    22.73
# 4    17.44
# 5    21.23
# 6    14.19
# 7    33.31
# 8    34.96
# 9    21.77
# Name: BMI, dtype: float64

# %% [markdown]
# - 🎯 The values in the 'BMI' column appeared to be incorrectly calculated, so they were recalculated and reassigned accordingly.

# %%
# We classified individuals into BMI (Body Mass Index) categories and created a new column accordingly.

def categorize_bmi(bmi):
    if bmi <= 18.5:
        return 'Underweight'
    elif 18.5 < bmi <= 24.99:
        return 'Normal weight'
    elif 25.0 <= bmi <= 29.99:
        return 'Overweight'
    elif 30.0 <= bmi <= 34.99:
        return 'Obesity Class 1'
    elif 35.0 <= bmi <= 39.99:
        return 'Obesity Class 2'
    else:
        return 'Obesity Class 3'

# %%
df['BMI_Category'] = df['BMI'].transform(categorize_bmi)
df['BMI_Category']
# Out:
# 0          Overweight
# 1          Overweight
# 2       Normal weight
# 3       Normal weight
# 4         Underweight
#             ...
# 1795    Normal weight
# 1796       Overweight
# 1797    Normal weight
# 1798      Underweight
# 1799    Normal weight
# Name: BMI_Category, Length: 1800, dtype: object

# %% [markdown]
# - 🎯 We categorized the body mass index (BMI) values based on the resulting BMI index according to standard classifications.

# %%
# Which workout type is more popular?

df["Workout_Type"].value_counts()
# Out:
# Workout_Type
# Strength    476
# Cardio      439
# Yoga        435
# HIIT        389
# Name: count, dtype: int64

# %%
plt.figure(figsize=(9,6))

plt.pie(x = df["Workout_Type"].value_counts(), labels = df["Workout_Type"].value_counts().index ,autopct="%1.2f%%")

plt.title("Popularity of Workout Types")

plt.show()

# %% [markdown]
# - 🎯 According to the graph, the most popular workout type is **Strength**, which is slightly ahead, while **HIIT** type is the lowest in popularity. The remaining workout types have relatively equal values.

# %%
# Let's compare the relationship between gender and weight (kg).

fig, ax = plt.subplots(1,2, figsize =(10,6))

sns.boxplot(data=df, x = "Gender", y = "Weight (kg)", palette="husl", ax = ax[0] )

sns.swarmplot(data=df, x = "Gender", y = "Weight (kg)", palette="viridis", ax = ax[1] )

plt.title("Gender and Weight Crr")

plt.tight_layout()

plt.show()

# %% [markdown]
# - 🎯  According to the bar plot, the weight range for men is between 50 kg and 78 kg, with more individuals having weights above 120 kg.
# - 🎯  For women, the weight range is between 55 kg and 80 kg.

# %%
# Do workout types vary according to gender, age, or BMI categories?

fig, ax = plt.subplots(1, 2, figsize=(14, 6))

sns.countplot(data=df, x='Workout_Type', hue='Gender', palette= "muted", ax=ax[0])
ax[0].set_title('Workout Types by Gender',fontsize = 14)
ax[0].set_xlabel('Workout Types',fontsize = 14)
ax[0].set_ylabel('Kişi Sayısı',fontsize = 14)
ax[0].legend(title='Cinsiyet',fontsize = 10)

sns.boxplot(data=df, x='Workout_Type', y='Age', hue="Gender", palette='husl', ax=ax[1])
ax[1].set_title('Workout Types by Age',fontsize = 14)
ax[1].set_xlabel('Workout Types',fontsize = 14)
ax[1].set_ylabel('Yaş', fontsize = 14)
ax[1].legend(loc = "upper center", fontsize = 10)


plt.tight_layout()
plt.show()

# %% [markdown]
# - 🎯 Men primarily prefer **Strength** and **Cardio** workout types.
# - 🎯 Women primarily prefer **HIIT** and **Yoga** workout types, as observed.

# %%
# Is there a relationship between BMI and calorie burning?
# We visualized this relationship using charts.

fig, ax = plt.subplots(1, 2, figsize=(14, 6))

sns.scatterplot(data=df, x='BMI', y='Calories_Burned', hue='Gender', palette='husl', ax=ax[0])
ax[0].set_title('BMI and Calorie Burning (By Gender)', fontsize=14)
ax[0].set_xlabel('BMI', fontsize=12)
ax[0].set_ylabel('Calorie Burning', fontsize=12)
ax[0].legend(title='Cinsiyet')

sns.regplot(data=df, x='BMI', y='Calories_Burned', color='red', ax=ax[1])
ax[1].set_title('BMI and Calorie Burning (Trendline)', fontsize=14)
ax[1].set_xlabel('BMI', fontsize=12)
ax[1].set_ylabel('Calorie Burning', fontsize=12)


plt.tight_layout()
plt.show()

# %% [markdown]
# - 🎯 BMI and calories burned are generally observed to be concentrated between 800 and 1400.

# %%
# We corrected the incorrect data in the Max_BPM column.
df["Max_BPM"] = df["Max_BPM"].str.strip("\\tn")

# %%
# We changed the data type of `max_bpm` from object to float.
df["Max_BPM"] = df["Max_BPM"].astype("float64")

# %%
# Then, we filled the missing values with the median.

df["Avg_BPM"].fillna(df["Avg_BPM"].median(), inplace=True)
df["Max_BPM"].fillna(df["Max_BPM"].median(), inplace=True)

# %%
# We created a new column to determine workout intensities.

df["Workout_Intensity"] = round(df["Avg_BPM"] / df["Max_BPM"],2)
df["Workout_Intensity"]
# Out:
# 0       0.87
# 1       0.94
# 2       0.89
# 3       0.90
# 4       0.95
#         ...
# 1795    0.77
# 1796    1.03
# 1797    0.69
# 1798    0.84
# 1799    0.85
# Name: Workout_Intensity, Length: 1800, dtype: float64

# %% [markdown]
# - 🎯 We filled the missing values in the `Avg_BPM` and `Max_BPM` columns with the median. After that, we created a new column to identify the workout intensity.

# %%
# Retrieve numeric column names.
df.select_dtypes(include=['number']).columns
# Out:
# Index(['Age', 'Weight (kg)', 'Height (m)', 'Max_BPM', 'Avg_BPM', 'Resting_BPM',
#        'Session_Duration (hours)', 'Calories_Burned', 'Fat_Percentage',
#        'Water_Intake (liters)', 'Workout_Frequency (days/week)',
#        'Experience_Level', 'BMI', 'Workout_Intensity'],
#       dtype='object')

# %%
# Retrieve column headers with data type 'object.
df.select_dtypes(include=['object']).columns
# Out:
# Index(['Gender', 'Workout_Type', 'BMI_Category'], dtype='object')

# %%
numerical_cols = df.select_dtypes(include=['number'])

# %%
# Numerical column values' correlation has been calculated.
numerical_cols = df.select_dtypes(include=['number'])
numerical_cols = numerical_cols.corr()
plt.figure(figsize=(8,6))
sns.heatmap(numerical_cols, annot=True, cmap = "coolwarm", fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# - 🎯 We examined the correlation of the numerical columns.
# - 🎯 Although there should be a correlation between 'Calories Burned' and 'Session Duration', due to incorrect and closely similar entries in the dataset, an analysis could not be performed accurately.

# %%
# We examined the relationship between exercise types and resting heart rate.
plt.figure(figsize=(10,6))
sns.barplot(data=df, x="Workout_Frequency (days/week)", y = "Resting_BPM", palette="viridis")
plt.show()

# %% [markdown]
# - 🎯 It has been observed that the resting BPM values should be lower for individuals who workout 5 days a week; however, there were errors in the dataset entries.
# - 🎯 According to this graph, individuals who workout 4 days a week have slightly lower resting BPM values.

# %%
# This code uses Seaborn to create scatter plots to examine the relationship between ,
# workout frequency (days per week) and BMI, calories burned, and resting BPM.
#  Each subplot visualizes the relationship between these variables, providing insights into the 
# impact of workout frequency on physical metrics. The plots clearly illustrate the direction and strength of the relationships.

correlations = df[['Workout_Frequency (days/week)', 'BMI', 'Calories_Burned', 'Resting_BPM']].corr()

plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.scatterplot(data=df, x='Workout_Frequency (days/week)', y='BMI', color='blue')
plt.title('Workout Frequency vs BMI')
plt.xlabel('Workout Frequency (gün/hafta)')
plt.ylabel('BMI')

plt.subplot(1, 3, 2)
sns.scatterplot(data=df, x='Workout_Frequency (days/week)', y='Calories_Burned', color='green')
plt.title('Workout Frequency vs Calories Burned')
plt.xlabel('Workout Frequency (gün/hafta)')
plt.ylabel('Calories Burned')


plt.subplot(1, 3, 3)
sns.scatterplot(data=df, x='Workout_Frequency (days/week)', y='Resting_BPM', color='red')
plt.title('Workout Frequency vs Resting BPM')
plt.xlabel('Workout Frequency (gün/hafta)')
plt.ylabel('Resting BPM')

plt.tight_layout()
plt.show()

# %% [markdown]
# - 🎯 Individuals with higher BMI values are generally distributed across the weeks without a specific pattern.

# %%
# We examined whether there is a difference in average heart rate (Avg_BPM) and calories burned as the Experience_Level increases.

plt.figure(figsize=(8,6))
sns.boxplot(data = df, x = "Experience_Level", y ="Calories_Burned")
plt.show()

# %% [markdown]
# 🎯 The `Experience_Level` shows that similar amounts of calories are burned across all levels.

# %%
# We examined whether the workout duration increases as the Experience_Level increases.
plt.figure(figsize=(8,6))
sns.barplot(data=df, x= "Experience_Level", y="Session_Duration (hours)", palette= "viridis")
plt.show()

# %% [markdown]
# - 🎯 Individuals with **Experience Level 2** have a longer average workout duration.
# - 🎯 It has been observed that individuals with **Experience Level 3** tend to have shorter workout durations compared to the others.

# %%
# Is there a significant difference in calories burned across different workout types?

plt.figure(figsize=(8,6))

sns.boxplot(data=df, x="Workout_Type", y = "Calories_Burned", palette="dark")
plt.title("Colories Burned by Workout Type")
plt.xlabel("Workout Type")
plt.ylabel("Colories Burned")
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# - 🎯 According to the dataset, more calories are burned in **Cardio** and **Yoga** workouts.

# %%
# How does the amount of calories burned change as the workout duration increases?
plt.figure(figsize=(10, 6))

sns.scatterplot(x='Session_Duration (hours)', y='Calories_Burned', data=df, palette='viridis')
plt.title('Calories Burned vs Session Duration')
plt.xlabel('Session Duration (hours)')
plt.ylabel('Calories Burned')
plt.show()

# %% [markdown]
# - 🎯 According to the dataset, individuals with workout durations between 1 and 1.4 hours generally burn between 800 and 1200 calories on average.

# %%
# Is there a relationship between Workout Type and BMI (Body Mass Index)?
plt.figure(figsize=(10, 6))

sns.boxplot(x='Workout_Type', y='BMI', data=df, palette='viridis')

plt.title('BMI by Workout Type')
plt.xlabel('Workout Type')
plt.ylabel('BMI')
plt.xticks(rotation=45) 
plt.show()

# %% [markdown]
# - 🎯 Individuals with **Strength** as their workout type tend to have higher BMI values.
# - 🎯 Individuals with **HIIT** as their workout type generally have higher BMI values compared to other workout types.
# - 🎯 There are no individuals with high BMI values in the **Yoga** workout type.

# %% [markdown]
# # <p style="background-color:whide;font-family:newtimeroman;font-size:100%;color:red;text-align:center;border-radius:20px 20px;"><b>**"Findings About the Dataset"**:</b></p>

# %% [markdown]
# - ✔️ In a nutshell,  this dataset was created for educational purposes.
# - ✔️ Filled in missing values
# - ✔️ Corrected incorrect entries using the replace method
# - ✔️ Compared and visualized many related headings
# - ✔️ Created new columns and attempted deeper analyses
# - ❌ Unfortunately, some commonly known comparisons were not meaningful due to the values in the dataset
# - ✔️ I believe the values in the dataset should be updated and reloaded
#
# - With best regards and love to everyone reading.
#
# - Participants in this training ;
#
# - https://www.kaggle.com/ozanmhrc
#
# - https://www.kaggle.com/abdullahkse
#
# - https://www.kaggle.com/zeripek
#
# - https://www.kaggle.com/hanifesin
#
# - https://www.kaggle.com/MasideKabakci
#
# - https://www.kaggle.com/semakurt
#
# - https://www.kaggle.com/fatmayerlikayazkurt
